# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 756

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_des = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description":city_des,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | victoria
# Processing Record 3 of Set 1 | sao felix do xingu
# Processing Record 4 of Set 1 | kodinsk
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | padang
# Processing Record 7 of Set 1 | ihosy
# Processing Record 8 of Set 1 | beringovskiy
# Processing Record 9 of Set 1 | lorengau
# Processing Record 10 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 1 | kamenka
# Processing Record 12 of Set 1 | ossora
# Processing Record 13 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 1 | kavaratti
# Processing Record 15 of Set 1 | maceio
# Processing Record 16 of Set 1 | port alfred
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | albany
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | bagdarin
# Processing Record 23 of Set 1 | provideniya
# Processing Record 24 of Set 1 | fare
# Processing Record 25 of Set 1 | urgut
# Processing Record 26 of Set 1 | san matias
# Processing Record 27 of Set 1 | kaitangata
# Processing Record 28 of Set 1 | leningradskiy
# Processing Record 29 of Set 1 | pandan
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | olean
# Processing Record 33 of Set 1 | arkhara
# Processing Record 34 of Set 1 | araria
# Processing Record 35 of Set 1 | salym
# Processing Record 36 of Set 1 | rawson
# Processing Record 37 of Set 1 | bredasdorp
# Processing Record 38 of Set 1 | pishin
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | thompson
# Processing Record 43 of Set 1 | luanda
# Processing Record 44 of Set 1 | bluff
# Processing Record 45 of Set 1 | khor
# Processing Record 46 of Set 1 | codrington
# Processing Record 47 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 48 of Set 1 | te anau
# Processing Record 49 of Set 1 | jacareacanga
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | ribeira grande
# Processing Record 2 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 3 of Set 2 | zempoala
# Processing Record 4 of Set 2 | torbay
# Processing Record 5 of Set 2 | lasa
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | faanui
# Processing Record 9 of Set 2 | phalaborwa
# Processing Record 10 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | christchurch
# Processing Record 13 of Set 2 | carnarvon
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | hilo
# Processing Record 16 of Set 2 | kainantu
# Processing Record 17 of Set 2 | puerto ayora
# Processing Record 18 of Set 2 | makakilo city
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | port hardy
# Processing Record 21 of Set 2 | soyo
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | port-gentil
# Processing Record 24 of Set 2 | bethel
# Processing Record 25 of Set 2 | sao filipe
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | pierre
# Processing Record 28 of Set 2 | sioux lookout
# Processing Record 29 of Set 2 | ilulissat
# Processing Record 30 of Set 2 | khromtau
# Processing Record 31 of Set 2 | churumuco
# City not found. Skipping...
# Processing Record 32 of Set 2 | monrovia
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | ostrovnoy
# Processing Record 35 of Set 2 | arlit
# Processing Record 36 of Set 2 | cherskiy
# Processing Record 37 of Set 2 | hun
# Processing Record 38 of Set 2 | lagoa
# Processing Record 39 of Set 2 | camana
# Processing Record 40 of Set 2 | olafsvik
# Processing Record 41 of Set 2 | bajo baudo
# City not found. Skipping...
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | geraldton
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | conroe
# Processing Record 47 of Set 2 | nizwa
# Processing Record 48 of Set 2 | payakumbuh
# Processing Record 49 of Set 2 | khour
# City not found. Skipping...
# Processing Record 50 of Set 2 | adelaide
# Processing Record 1 of Set 3 | poso
# Processing Record 2 of Set 3 | inuvik
# Processing Record 3 of Set 3 | saint george
# Processing Record 4 of Set 3 | coquimbo
# Processing Record 5 of Set 3 | avarua
# Processing Record 6 of Set 3 | satitoa
# City not found. Skipping...
# Processing Record 7 of Set 3 | litoral del san juan
# City not found. Skipping...
# Processing Record 8 of Set 3 | ulladulla
# Processing Record 9 of Set 3 | ancud
# Processing Record 10 of Set 3 | norman wells
# Processing Record 11 of Set 3 | esperance
# Processing Record 12 of Set 3 | bengkulu
# Processing Record 13 of Set 3 | atasu
# Processing Record 14 of Set 3 | terra rica
# Processing Record 15 of Set 3 | caravelas
# Processing Record 16 of Set 3 | nome
# Processing Record 17 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | iwanai
# Processing Record 20 of Set 3 | jequitinhonha
# Processing Record 21 of Set 3 | lakes entrance
# Processing Record 22 of Set 3 | surgut
# Processing Record 23 of Set 3 | pangnirtung
# Processing Record 24 of Set 3 | anar darreh
# City not found. Skipping...
# Processing Record 25 of Set 3 | izumo
# Processing Record 26 of Set 3 | port elizabeth
# Processing Record 27 of Set 3 | mataura
# Processing Record 28 of Set 3 | ponta do sol
# Processing Record 29 of Set 3 | raurkela
# City not found. Skipping...
# Processing Record 30 of Set 3 | arapiraca
# Processing Record 31 of Set 3 | santa isabel do rio negro
# Processing Record 32 of Set 3 | vaini
# Processing Record 33 of Set 3 | natchez
# Processing Record 34 of Set 3 | bubaque
# Processing Record 35 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | uniao da victoria
# City not found. Skipping...
# Processing Record 38 of Set 3 | baoning
# Processing Record 39 of Set 3 | dikson
# Processing Record 40 of Set 3 | kapchorwa
# Processing Record 41 of Set 3 | ornskoldsvik
# Processing Record 42 of Set 3 | noshiro
# Processing Record 43 of Set 3 | beroroha
# Processing Record 44 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 3 | butaritari
# Processing Record 46 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 3 | half moon bay
# Processing Record 48 of Set 3 | cozumel
# Processing Record 49 of Set 3 | naze
# Processing Record 50 of Set 3 | bobrovka
# Processing Record 1 of Set 4 | toledo
# Processing Record 2 of Set 4 | faya
# Processing Record 3 of Set 4 | bridgetown
# Processing Record 4 of Set 4 | tuktoyaktuk
# Processing Record 5 of Set 4 | batagay-alyta
# Processing Record 6 of Set 4 | sorland
# Processing Record 7 of Set 4 | carutapera
# Processing Record 8 of Set 4 | port-cartier
# Processing Record 9 of Set 4 | eldorado
# Processing Record 10 of Set 4 | poum
# Processing Record 11 of Set 4 | imbituba
# Processing Record 12 of Set 4 | nioro
# Processing Record 13 of Set 4 | sabha
# Processing Record 14 of Set 4 | georgetown
# Processing Record 15 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 4 | fairbanks
# Processing Record 17 of Set 4 | eureka
# Processing Record 18 of Set 4 | lahaina
# Processing Record 19 of Set 4 | talnakh
# Processing Record 20 of Set 4 | afmadu
# City not found. Skipping...
# Processing Record 21 of Set 4 | adrar
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | katsuura
# Processing Record 24 of Set 4 | ayagoz
# Processing Record 25 of Set 4 | talaya
# Processing Record 26 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 4 | tiznit
# Processing Record 28 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 4 | port hueneme
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | cascais
# Processing Record 32 of Set 4 | altenholz
# Processing Record 33 of Set 4 | gat
# Processing Record 34 of Set 4 | asau
# Processing Record 35 of Set 4 | yar-sale
# Processing Record 36 of Set 4 | dekoa
# City not found. Skipping...
# Processing Record 37 of Set 4 | tuatapere
# Processing Record 38 of Set 4 | arraial do cabo
# Processing Record 39 of Set 4 | agirish
# Processing Record 40 of Set 4 | moncarapacho
# Processing Record 41 of Set 4 | livaderon
# City not found. Skipping...
# Processing Record 42 of Set 4 | vestmannaeyjar
# Processing Record 43 of Set 4 | beitbridge
# Processing Record 44 of Set 4 | egvekinot
# Processing Record 45 of Set 4 | tiksi
# Processing Record 46 of Set 4 | khandyga
# Processing Record 47 of Set 4 | mandera
# Processing Record 48 of Set 4 | lazaro cardenas
# Processing Record 49 of Set 4 | kamaishi
# Processing Record 50 of Set 4 | cizre
# Processing Record 1 of Set 5 | kushima
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | saravena
# Processing Record 4 of Set 5 | san patricio
# Processing Record 5 of Set 5 | ixtapa
# Processing Record 6 of Set 5 | castro
# Processing Record 7 of Set 5 | homorod-de jos
# City not found. Skipping...
# Processing Record 8 of Set 5 | vila velha
# Processing Record 9 of Set 5 | severo-kurilsk
# Processing Record 10 of Set 5 | namibe
# Processing Record 11 of Set 5 | mercedes
# Processing Record 12 of Set 5 | krasnoselkup
# Processing Record 13 of Set 5 | sangar
# Processing Record 14 of Set 5 | northam
# Processing Record 15 of Set 5 | fomboni
# Processing Record 16 of Set 5 | los llanos de aridane
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 19 of Set 5 | shiyan
# Processing Record 20 of Set 5 | praya
# Processing Record 21 of Set 5 | mahebourg
# Processing Record 22 of Set 5 | nikolskoye
# Processing Record 23 of Set 5 | port lincoln
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | ust-ilimsk
# Processing Record 26 of Set 5 | conceicao do araguaia
# Processing Record 27 of Set 5 | brae
# Processing Record 28 of Set 5 | ye
# City not found. Skipping...
# Processing Record 29 of Set 5 | les cayes
# Processing Record 30 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 31 of Set 5 | mananjary
# Processing Record 32 of Set 5 | prieska
# Processing Record 33 of Set 5 | senmonorom
# City not found. Skipping...
# Processing Record 34 of Set 5 | santa cruz
# Processing Record 35 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 5 | oxelosund
# Processing Record 37 of Set 5 | kalemie
# Processing Record 38 of Set 5 | edson
# Processing Record 39 of Set 5 | yablonovo
# Processing Record 40 of Set 5 | labuhan
# Processing Record 41 of Set 5 | new norfolk
# Processing Record 42 of Set 5 | balikpapan
# Processing Record 43 of Set 5 | pevek
# Processing Record 44 of Set 5 | kita
# Processing Record 45 of Set 5 | kimbe
# Processing Record 46 of Set 5 | alofi
# Processing Record 47 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 48 of Set 5 | seydisehir
# Processing Record 49 of Set 5 | pochutla
# Processing Record 50 of Set 5 | tabou
# Processing Record 1 of Set 6 | sao caetano de odivelas
# Processing Record 2 of Set 6 | khonsa
# Processing Record 3 of Set 6 | wajir
# Processing Record 4 of Set 6 | turukhansk
# Processing Record 5 of Set 6 | opuwo
# Processing Record 6 of Set 6 | wahiawa
# Processing Record 7 of Set 6 | nantucket
# Processing Record 8 of Set 6 | bangassou
# Processing Record 9 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 6 | sao goncalo do amarante
# Processing Record 11 of Set 6 | youhao
# Processing Record 12 of Set 6 | abu dhabi
# Processing Record 13 of Set 6 | port macquarie
# Processing Record 14 of Set 6 | taoudenni
# Processing Record 15 of Set 6 | pacific grove
# Processing Record 16 of Set 6 | valparaiso
# Processing Record 17 of Set 6 | nabire
# Processing Record 18 of Set 6 | saldanha
# Processing Record 19 of Set 6 | dhrol
# Processing Record 20 of Set 6 | jining
# Processing Record 21 of Set 6 | havelock
# Processing Record 22 of Set 6 | nouadhibou
# Processing Record 23 of Set 6 | alyangula
# Processing Record 24 of Set 6 | manokwari
# Processing Record 25 of Set 6 | dalbandin
# Processing Record 26 of Set 6 | awjilah
# Processing Record 27 of Set 6 | fengzhen
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | la ronge
# Processing Record 30 of Set 6 | louisville
# Processing Record 31 of Set 6 | slave lake
# Processing Record 32 of Set 6 | krasnotorka
# Processing Record 33 of Set 6 | dzhebariki-khaya
# Processing Record 34 of Set 6 | kanniyakumari
# Processing Record 35 of Set 6 | hithadhoo
# Processing Record 36 of Set 6 | betafo
# Processing Record 37 of Set 6 | piacabucu
# Processing Record 38 of Set 6 | ahipara
# Processing Record 39 of Set 6 | dicabisagan
# Processing Record 40 of Set 6 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 6 | andenes
# Processing Record 42 of Set 6 | havre-saint-pierre
# Processing Record 43 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 6 | ribeira brava
# Processing Record 45 of Set 6 | salalah
# Processing Record 46 of Set 6 | whitianga
# Processing Record 47 of Set 6 | burica
# City not found. Skipping...
# Processing Record 48 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 6 | belaya gora
# Processing Record 50 of Set 6 | puerto madero
# Processing Record 1 of Set 7 | srostki
# Processing Record 2 of Set 7 | khatanga
# Processing Record 3 of Set 7 | turbat
# Processing Record 4 of Set 7 | gravdal
# Processing Record 5 of Set 7 | nemuro
# Processing Record 6 of Set 7 | nioki
# Processing Record 7 of Set 7 | mudkhed
# Processing Record 8 of Set 7 | bama
# Processing Record 9 of Set 7 | constitucion
# Processing Record 10 of Set 7 | mpika
# Processing Record 11 of Set 7 | seoul
# Processing Record 12 of Set 7 | riosucio
# Processing Record 13 of Set 7 | kokstad
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | hay river
# Processing Record 16 of Set 7 | sakakah
# Processing Record 17 of Set 7 | los alamos
# Processing Record 18 of Set 7 | rancho santa margarita
# Processing Record 19 of Set 7 | bilibino
# Processing Record 20 of Set 7 | jiangyou
# Processing Record 21 of Set 7 | porbandar
# Processing Record 22 of Set 7 | marsa matruh
# Processing Record 23 of Set 7 | kanchanaburi
# Processing Record 24 of Set 7 | of
# City not found. Skipping...
# Processing Record 25 of Set 7 | sitka
# Processing Record 26 of Set 7 | chuy
# Processing Record 27 of Set 7 | mackay
# Processing Record 28 of Set 7 | verkhnevilyuysk
# Processing Record 29 of Set 7 | quelimane
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | vao
# Processing Record 32 of Set 7 | gamba
# Processing Record 33 of Set 7 | poronaysk
# Processing Record 34 of Set 7 | probolinggo
# Processing Record 35 of Set 7 | cabo san lucas
# Processing Record 36 of Set 7 | koslan
# Processing Record 37 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 38 of Set 7 | karpinsk
# Processing Record 39 of Set 7 | alanya
# Processing Record 40 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 41 of Set 7 | ulkan
# Processing Record 42 of Set 7 | panorama
# Processing Record 43 of Set 7 | miri
# Processing Record 44 of Set 7 | biak
# Processing Record 45 of Set 7 | serowe
# Processing Record 46 of Set 7 | lata
# Processing Record 47 of Set 7 | port blair
# Processing Record 48 of Set 7 | mocuba
# Processing Record 49 of Set 7 | labuan
# Processing Record 50 of Set 7 | mount pleasant
# Processing Record 1 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 2 of Set 8 | ivybridge
# Processing Record 3 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 8 | tessalit
# Processing Record 5 of Set 8 | cap malheureux
# Processing Record 6 of Set 8 | kyzyl-suu
# Processing Record 7 of Set 8 | rocha
# Processing Record 8 of Set 8 | sao francisco
# Processing Record 9 of Set 8 | kichera
# Processing Record 10 of Set 8 | bambous virieux
# Processing Record 11 of Set 8 | wenzhou
# Processing Record 12 of Set 8 | adre
# Processing Record 13 of Set 8 | cockburn town
# Processing Record 14 of Set 8 | divnogorsk
# Processing Record 15 of Set 8 | saskylakh
# Processing Record 16 of Set 8 | souillac
# Processing Record 17 of Set 8 | hamilton
# Processing Record 18 of Set 8 | carlsbad
# Processing Record 19 of Set 8 | manlleu
# Processing Record 20 of Set 8 | kwinana
# Processing Record 21 of Set 8 | kaeo
# Processing Record 22 of Set 8 | kenai
# Processing Record 23 of Set 8 | manadhoo
# Processing Record 24 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 8 | correntina
# Processing Record 26 of Set 8 | airai
# Processing Record 27 of Set 8 | yarmouth
# Processing Record 28 of Set 8 | jinchang
# Processing Record 29 of Set 8 | fulacunda
# City not found. Skipping...
# Processing Record 30 of Set 8 | longyearbyen
# Processing Record 31 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 32 of Set 8 | payo
# Processing Record 33 of Set 8 | linxia
# Processing Record 34 of Set 8 | heihe
# Processing Record 35 of Set 8 | huarmey
# Processing Record 36 of Set 8 | zheleznodorozhnyy
# Processing Record 37 of Set 8 | teya
# Processing Record 38 of Set 8 | komsomolskiy
# Processing Record 39 of Set 8 | grand gaube
# Processing Record 40 of Set 8 | willowmore
# Processing Record 41 of Set 8 | zhigalovo
# Processing Record 42 of Set 8 | chokurdakh
# Processing Record 43 of Set 8 | lavrentiya
# Processing Record 44 of Set 8 | zavitinsk
# Processing Record 45 of Set 8 | khartoum
# Processing Record 46 of Set 8 | plettenberg bay
# Processing Record 47 of Set 8 | margate
# Processing Record 48 of Set 8 | paysandu
# Processing Record 49 of Set 8 | moryakovskiy zaton
# Processing Record 50 of Set 8 | morondava
# Processing Record 1 of Set 9 | palauig
# Processing Record 2 of Set 9 | praia da vitoria
# Processing Record 3 of Set 9 | rio grande
# Processing Record 4 of Set 9 | dunedin
# Processing Record 5 of Set 9 | westerland
# Processing Record 6 of Set 9 | vardo
# Processing Record 7 of Set 9 | najran
# Processing Record 8 of Set 9 | pilar
# Processing Record 9 of Set 9 | hofn
# Processing Record 10 of Set 9 | tallahassee
# Processing Record 11 of Set 9 | laurel
# Processing Record 12 of Set 9 | baishishan
# Processing Record 13 of Set 9 | camacha
# Processing Record 14 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 15 of Set 9 | gimli
# Processing Record 16 of Set 9 | qasigiannguit
# Processing Record 17 of Set 9 | tigil
# Processing Record 18 of Set 9 | marmande
# Processing Record 19 of Set 9 | mathathane
# Processing Record 20 of Set 9 | bogande
# Processing Record 21 of Set 9 | yulara
# Processing Record 22 of Set 9 | maridi
# Processing Record 23 of Set 9 | herat
# Processing Record 24 of Set 9 | devgarh
# Processing Record 25 of Set 9 | america dourada
# Processing Record 26 of Set 9 | eirunepe
# Processing Record 27 of Set 9 | karaman
# Processing Record 28 of Set 9 | loralai
# Processing Record 29 of Set 9 | altamont
# Processing Record 30 of Set 9 | paita
# Processing Record 31 of Set 9 | leeton
# Processing Record 32 of Set 9 | mount isa
# Processing Record 33 of Set 9 | elizabeth city
# Processing Record 34 of Set 9 | kasongo-lunda
# Processing Record 35 of Set 9 | xianshuigu
# Processing Record 36 of Set 9 | victor harbor
# Processing Record 37 of Set 9 | cotonou
# Processing Record 38 of Set 9 | samarai
# Processing Record 39 of Set 9 | solnechnyy
# Processing Record 40 of Set 9 | corrientes
# Processing Record 41 of Set 9 | hervey bay
# Processing Record 42 of Set 9 | mazamari
# Processing Record 43 of Set 9 | agsu
# City not found. Skipping...
# Processing Record 44 of Set 9 | fairview
# Processing Record 45 of Set 9 | ambodifototra
# City not found. Skipping...
# Processing Record 46 of Set 9 | san luis
# Processing Record 47 of Set 9 | matara
# Processing Record 48 of Set 9 | touros
# Processing Record 49 of Set 9 | grindavik
# Processing Record 50 of Set 9 | zhanaozen
# Processing Record 1 of Set 10 | yerbogachen
# Processing Record 2 of Set 10 | salinopolis
# Processing Record 3 of Set 10 | lompoc
# Processing Record 4 of Set 10 | bayir
# Processing Record 5 of Set 10 | katangli
# Processing Record 6 of Set 10 | clyde river
# Processing Record 7 of Set 10 | kuala terengganu
# Processing Record 8 of Set 10 | olinda
# Processing Record 9 of Set 10 | cuxhaven
# Processing Record 10 of Set 10 | deputatskiy
# Processing Record 11 of Set 10 | nago
# Processing Record 12 of Set 10 | sliedrecht
# Processing Record 13 of Set 10 | bud
# Processing Record 14 of Set 10 | kathmandu
# Processing Record 15 of Set 10 | brandon
# Processing Record 16 of Set 10 | djambala
# Processing Record 17 of Set 10 | comodoro rivadavia
# Processing Record 18 of Set 10 | moron
# Processing Record 19 of Set 10 | karratha
# Processing Record 20 of Set 10 | saint-francois
# Processing Record 21 of Set 10 | sayyan
# Processing Record 22 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 23 of Set 10 | pangody
# Processing Record 24 of Set 10 | erzin
# Processing Record 25 of Set 10 | anloga
# Processing Record 26 of Set 10 | nanortalik
# Processing Record 27 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 10 | paradwip
# City not found. Skipping...
# Processing Record 29 of Set 10 | cuenca
# Processing Record 30 of Set 10 | hope
# Processing Record 31 of Set 10 | podor
# Processing Record 32 of Set 10 | thinadhoo
# Processing Record 33 of Set 10 | paraiso
# Processing Record 34 of Set 10 | shelburne
# Processing Record 35 of Set 10 | zhezkazgan
# Processing Record 36 of Set 10 | jaguey grande
# Processing Record 37 of Set 10 | novyy urengoy
# Processing Record 38 of Set 10 | halifax
# Processing Record 39 of Set 10 | muros
# Processing Record 40 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 10 | maragogi
# Processing Record 42 of Set 10 | dudinka
# Processing Record 43 of Set 10 | onega
# Processing Record 44 of Set 10 | kalabo
# Processing Record 45 of Set 10 | san-pedro
# Processing Record 46 of Set 10 | hue
# Processing Record 47 of Set 10 | viedma
# Processing Record 48 of Set 10 | paka
# Processing Record 49 of Set 10 | ginir
# Processing Record 50 of Set 10 | saint-leu
# Processing Record 1 of Set 11 | lapeer
# Processing Record 2 of Set 11 | evensk
# Processing Record 3 of Set 11 | cayenne
# Processing Record 4 of Set 11 | yarada
# Processing Record 5 of Set 11 | chekhov
# Processing Record 6 of Set 11 | raudeberg
# Processing Record 7 of Set 11 | lucapa
# Processing Record 8 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 11 | chapais
# Processing Record 10 of Set 11 | kilmallock
# Processing Record 11 of Set 11 | anchorage
# Processing Record 12 of Set 11 | freeport
# Processing Record 13 of Set 11 | teknaf
# Processing Record 14 of Set 11 | dingle
# Processing Record 15 of Set 11 | gondanglegi
# Processing Record 16 of Set 11 | shieli
# Processing Record 17 of Set 11 | borogontsy
# Processing Record 18 of Set 11 | ocos
# Processing Record 19 of Set 11 | tiarei
# Processing Record 20 of Set 11 | fortuna
# Processing Record 21 of Set 11 | hohhot
# Processing Record 22 of Set 11 | balad
# Processing Record 23 of Set 11 | pak thong chai
# Processing Record 24 of Set 11 | saint-pierre
# Processing Record 25 of Set 11 | acarau
# Processing Record 26 of Set 11 | livingston
# Processing Record 27 of Set 11 | naron
# Processing Record 28 of Set 11 | reutlingen
# Processing Record 29 of Set 11 | tuensang
# Processing Record 30 of Set 11 | yichun
# Processing Record 31 of Set 11 | pomerode
# Processing Record 32 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 33 of Set 11 | san lorenzo
# Processing Record 34 of Set 11 | tabuk
# Processing Record 35 of Set 11 | aksarayskiy
# Processing Record 36 of Set 11 | urengoy
# Processing Record 37 of Set 11 | monte alegre
# Processing Record 38 of Set 11 | sao jose da coroa grande
# Processing Record 39 of Set 11 | atbasar
# Processing Record 40 of Set 11 | mayo
# Processing Record 41 of Set 11 | severo-yeniseyskiy
# Processing Record 42 of Set 11 | kangaatsiaq
# Processing Record 43 of Set 11 | broome
# Processing Record 44 of Set 11 | el jicaro
# Processing Record 45 of Set 11 | alice springs
# Processing Record 46 of Set 11 | palora
# Processing Record 47 of Set 11 | nazira
# Processing Record 48 of Set 11 | abu samrah
# Processing Record 49 of Set 11 | nanning
# Processing Record 50 of Set 11 | iranshahr
# Processing Record 1 of Set 12 | goundam
# Processing Record 2 of Set 12 | bandarbeyla
# Processing Record 3 of Set 12 | mount gambier
# Processing Record 4 of Set 12 | zvishavane
# Processing Record 5 of Set 12 | linqiong
# Processing Record 6 of Set 12 | makat
# Processing Record 7 of Set 12 | kayseri
# Processing Record 8 of Set 12 | nisia floresta
# Processing Record 9 of Set 12 | gribanovskiy
# Processing Record 10 of Set 12 | conceicao da barra
# Processing Record 11 of Set 12 | thaba-tseka
# Processing Record 12 of Set 12 | reconquista
# Processing Record 13 of Set 12 | luderitz
# Processing Record 14 of Set 12 | tutoia
# Processing Record 15 of Set 12 | kiruna
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | liliani
# Processing Record 18 of Set 12 | terrace
# Processing Record 19 of Set 12 | tura
# Processing Record 20 of Set 12 | chicama
# Processing Record 21 of Set 12 | bonavista
# Processing Record 22 of Set 12 | berbera
# Processing Record 23 of Set 12 | arona
# Processing Record 24 of Set 12 | ola
# Processing Record 25 of Set 12 | lalomanu
# City not found. Skipping...
# Processing Record 26 of Set 12 | massaguet
# Processing Record 27 of Set 12 | marulanda
# Processing Record 28 of Set 12 | santa rita
# Processing Record 29 of Set 12 | lodingen
# Processing Record 30 of Set 12 | kapoeta
# Processing Record 31 of Set 12 | takoradi
# Processing Record 32 of Set 12 | aksarka
# Processing Record 33 of Set 12 | mantua
# Processing Record 34 of Set 12 | portland
# Processing Record 35 of Set 12 | lanxi
# Processing Record 36 of Set 12 | tonj
# Processing Record 37 of Set 12 | hire
# City not found. Skipping...
# Processing Record 38 of Set 12 | aspindza
# Processing Record 39 of Set 12 | martapura
# Processing Record 40 of Set 12 | sidi qasim
# City not found. Skipping...
# Processing Record 41 of Set 12 | hambantota
# Processing Record 42 of Set 12 | mansa
# Processing Record 43 of Set 12 | estelle
# Processing Record 44 of Set 12 | acapulco
# Processing Record 45 of Set 12 | kalmunai
# Processing Record 46 of Set 12 | mackenzie
# Processing Record 47 of Set 12 | areia branca
# Processing Record 48 of Set 12 | san rafael
# Processing Record 49 of Set 12 | mumford
# Processing Record 50 of Set 12 | aguimes
# Processing Record 1 of Set 13 | noyabrsk
# Processing Record 2 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 3 of Set 13 | zhongxing
# Processing Record 4 of Set 13 | haines junction
# Processing Record 5 of Set 13 | golden
# Processing Record 6 of Set 13 | jacksonville
# Processing Record 7 of Set 13 | qaracala
# Processing Record 8 of Set 13 | henzada
# City not found. Skipping...
# Processing Record 9 of Set 13 | zarand
# Processing Record 10 of Set 13 | keelung
# Processing Record 11 of Set 13 | bumba
# Processing Record 12 of Set 13 | bemidji
# Processing Record 13 of Set 13 | mitsamiouli
# Processing Record 14 of Set 13 | saint anthony
# Processing Record 15 of Set 13 | zhigansk
# Processing Record 16 of Set 13 | tarko-sale
# Processing Record 17 of Set 13 | kununurra
# Processing Record 18 of Set 13 | ust-tsilma
# Processing Record 19 of Set 13 | baruun-urt
# Processing Record 20 of Set 13 | namatanai
# Processing Record 21 of Set 13 | san diego
# Processing Record 22 of Set 13 | bonthe
# Processing Record 23 of Set 13 | sabang
# Processing Record 24 of Set 13 | monroe
# Processing Record 25 of Set 13 | mastic beach
# Processing Record 26 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 27 of Set 13 | tongren
# Processing Record 28 of Set 13 | dubenskiy
# City not found. Skipping...
# Processing Record 29 of Set 13 | matagami
# Processing Record 30 of Set 13 | torres
# Processing Record 31 of Set 13 | ushtobe
# Processing Record 32 of Set 13 | sao miguel do araguaia
# Processing Record 33 of Set 13 | guaruja
# Processing Record 34 of Set 13 | nizhniy tsasuchey
# Processing Record 35 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 13 | orlik
# Processing Record 37 of Set 13 | terni
# Processing Record 38 of Set 13 | tagbac
# Processing Record 39 of Set 13 | sarkand
# Processing Record 40 of Set 13 | kaili
# Processing Record 41 of Set 13 | jertih
# Processing Record 42 of Set 13 | nouakchott
# Processing Record 43 of Set 13 | juneau
# Processing Record 44 of Set 13 | prado
# Processing Record 45 of Set 13 | sao joao da barra
# Processing Record 46 of Set 13 | suntar
# Processing Record 47 of Set 13 | ati
# Processing Record 48 of Set 13 | isiolo
# Processing Record 49 of Set 13 | ust-maya
# Processing Record 50 of Set 13 | porto novo
# Processing Record 1 of Set 14 | becej
# Processing Record 2 of Set 14 | bismarck
# Processing Record 3 of Set 14 | axim
# Processing Record 4 of Set 14 | gorom-gorom
# Processing Record 5 of Set 14 | fortuna foothills
# Processing Record 6 of Set 14 | daru
# Processing Record 7 of Set 14 | mahon
# Processing Record 8 of Set 14 | kargasok
# Processing Record 9 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 10 of Set 14 | belvidere
# Processing Record 11 of Set 14 | nishihara
# Processing Record 12 of Set 14 | fartura
# Processing Record 13 of Set 14 | jumla
# Processing Record 14 of Set 14 | beidao
# Processing Record 15 of Set 14 | belyy yar
# Processing Record 16 of Set 14 | whitehorse
# Processing Record 17 of Set 14 | bambanglipuro
# Processing Record 18 of Set 14 | isangel
# Processing Record 19 of Set 14 | gubkinskiy
# Processing Record 20 of Set 14 | roebourne
# Processing Record 21 of Set 14 | ipixuna
# Processing Record 22 of Set 14 | arman
# Processing Record 23 of Set 14 | araceli
# Processing Record 24 of Set 14 | palmer
# Processing Record 25 of Set 14 | yerofey pavlovich
# Processing Record 26 of Set 14 | kudahuvadhoo
# Processing Record 27 of Set 14 | mao
# Processing Record 28 of Set 14 | oktyabrskiy
# Processing Record 29 of Set 14 | miraflores
# Processing Record 30 of Set 14 | walvis bay
# Processing Record 31 of Set 14 | asfi
# Processing Record 32 of Set 14 | tupiza
# Processing Record 33 of Set 14 | quatre cocos
# Processing Record 34 of Set 14 | salamiyah
# Processing Record 35 of Set 14 | amahai
# Processing Record 36 of Set 14 | gandajika
# Processing Record 37 of Set 14 | petauke
# Processing Record 38 of Set 14 | karpathos
# Processing Record 39 of Set 14 | puerto rondon
# Processing Record 40 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 41 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 14 | baghdad
# Processing Record 43 of Set 14 | deming
# Processing Record 44 of Set 14 | shingu
# Processing Record 45 of Set 14 | maghama
# City not found. Skipping...
# Processing Record 46 of Set 14 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 14 | atherton
# Processing Record 48 of Set 14 | aswan
# Processing Record 49 of Set 14 | patur
# Processing Record 50 of Set 14 | taltal
# Processing Record 1 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 2 of Set 15 | bertoua
# Processing Record 3 of Set 15 | shirokiy
# Processing Record 4 of Set 15 | valenca
# Processing Record 5 of Set 15 | bowen
# Processing Record 6 of Set 15 | hovd
# Processing Record 7 of Set 15 | kapit
# Processing Record 8 of Set 15 | honningsvag
# Processing Record 9 of Set 15 | sombrio
# Processing Record 10 of Set 15 | antofagasta
# Processing Record 11 of Set 15 | kharp
# Processing Record 12 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 15 | kloulklubed
# Processing Record 14 of Set 15 | saint-michel-des-saints
# Processing Record 15 of Set 15 | den helder
# Processing Record 16 of Set 15 | aguia branca
# Processing Record 17 of Set 15 | katherine
# Processing Record 18 of Set 15 | yeppoon
# Processing Record 19 of Set 15 | trelew
# Processing Record 20 of Set 15 | pizhma
# Processing Record 21 of Set 15 | qostanay
# Processing Record 22 of Set 15 | chiniot
# Processing Record 23 of Set 15 | qaqortoq
# Processing Record 24 of Set 15 | laguna
# Processing Record 25 of Set 15 | aljezur
# Processing Record 26 of Set 15 | san carlos de bariloche
# Processing Record 27 of Set 15 | meadow lake
# Processing Record 28 of Set 15 | mehran
# Processing Record 29 of Set 15 | kurchum
# Processing Record 30 of Set 15 | boyolangu
# Processing Record 31 of Set 15 | mucurapo
# Processing Record 32 of Set 15 | tammisaari
# Processing Record 33 of Set 15 | pekan
# Processing Record 34 of Set 15 | ondangwa
# Processing Record 35 of Set 15 | ust-kan
# Processing Record 36 of Set 15 | tofield
# Processing Record 37 of Set 15 | diplo
# Processing Record 38 of Set 15 | beloha
# Processing Record 39 of Set 15 | zhuanghe
# Processing Record 40 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 41 of Set 15 | sterling
# Processing Record 42 of Set 15 | gobabis
# Processing Record 43 of Set 15 | innisfail
# Processing Record 44 of Set 15 | mahajanga
# Processing Record 45 of Set 15 | turayf
# Processing Record 46 of Set 15 | henties bay
# Processing Record 47 of Set 15 | bathsheba
# Processing Record 48 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 15 | tual
# Processing Record 50 of Set 15 | umm lajj
# Processing Record 1 of Set 16 | garowe
# Processing Record 2 of Set 16 | soloneshnoye
# Processing Record 3 of Set 16 | gejiu
# Processing Record 4 of Set 16 | marawi
# Processing Record 5 of Set 16 | devils lake
# Processing Record 6 of Set 16 | voh
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Rikitea -23.1203 -134.9692     75.90        74          99
# 1              Victoria  22.2855  114.1577     68.32        87           0
# 2    Sao Felix Do Xingu  -6.6447  -51.9950     78.78        94         100
# 3               Kodinsk  58.6881   99.1844     19.18        92         100
# 4               Iqaluit  63.7506  -68.5145    -11.31        69          20
# ..                  ...      ...       ...       ...       ...         ...
# 681        Soloneshnoye  51.6544   84.3197     14.40        81          99
# 682               Gejiu  23.3060  103.1635     46.99        95          96
# 683              Marawi   7.9986  124.2928     66.65        94          77
# 684         Devils Lake  48.1128  -98.8651     27.95        74           1
# 685                 Voh -20.9667  164.7000     83.89        69          99
#
#      Wind Speed Current Description Country                 Date
# 0         16.17     overcast clouds      PF  2021-12-11 20:19:04
# 1          3.00           clear sky      HK  2021-12-11 20:14:15
# 2          1.90     overcast clouds      BR  2021-12-11 20:19:04
# 3          7.40     overcast clouds      RU  2021-12-11 20:19:04
# 4          5.01          few clouds      CA  2021-12-11 20:19:05
# ..          ...                 ...     ...                  ...
# 681        5.79     overcast clouds      RU  2021-12-11 20:37:25
# 682        3.94     overcast clouds      CN  2021-12-11 20:37:26
# 683        1.90       broken clouds      PH  2021-12-11 20:37:26
# 684       11.99           clear sky      US  2021-12-11 20:37:26
# 685        4.65     overcast clouds      NC  2021-12-11 20:37:27
#
# [686 rows x 10 columns]

# %%
new_city_data_df = city_data_df.drop_duplicates()
new_city_data_df
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0               Rikitea -23.1203 -134.9692     75.90        74          99
# 1              Victoria  22.2855  114.1577     68.32        87           0
# 2    Sao Felix Do Xingu  -6.6447  -51.9950     78.78        94         100
# 3               Kodinsk  58.6881   99.1844     19.18        92         100
# 4               Iqaluit  63.7506  -68.5145    -11.31        69          20
# ..                  ...      ...       ...       ...       ...         ...
# 681        Soloneshnoye  51.6544   84.3197     14.40        81          99
# 682               Gejiu  23.3060  103.1635     46.99        95          96
# 683              Marawi   7.9986  124.2928     66.65        94          77
# 684         Devils Lake  48.1128  -98.8651     27.95        74           1
# 685                 Voh -20.9667  164.7000     83.89        69          99
#
#      Wind Speed Current Description Country                 Date
# 0         16.17     overcast clouds      PF  2021-12-11 20:19:04
# 1          3.00           clear sky      HK  2021-12-11 20:14:15
# 2          1.90     overcast clouds      BR  2021-12-11 20:19:04
# 3          7.40     overcast clouds      RU  2021-12-11 20:19:04
# 4          5.01          few clouds      CA  2021-12-11 20:19:05
# ..          ...                 ...     ...                  ...
# 681        5.79     overcast clouds      RU  2021-12-11 20:37:25
# 682        3.94     overcast clouds      CN  2021-12-11 20:37:26
# 683        1.90       broken clouds      PH  2021-12-11 20:37:26
# 684       11.99           clear sky      US  2021-12-11 20:37:26
# 685        4.65     overcast clouds      NC  2021-12-11 20:37:27
#
# [686 rows x 10 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
new_city_data_df.to_csv(output_data_file, index_label="City_ID")
